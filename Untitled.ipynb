# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("dog_breeds.csv")

# %%
print(data.columns)
# Out:
# Index(['Breed', 'height_cm', 'mass_kg'], dtype='object')

# %%
sns.relplot(x='height_cm',y='mass_kg',data=data,kind="scatter")

# %%
data["height_cm"].hist(bins=100)
plt.show()
